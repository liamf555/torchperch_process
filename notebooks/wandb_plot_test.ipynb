# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: tu18537. Use `wandb login --relogin` to force relogin
# True

# %%
# %wandb tu18537/pymxs
# Out:
# <iframe src='https://wandb.ai/tu18537/pymxs/workspace?jupyter=true' style='border:none;width:100%;height:420px;'></iframe>

# %%
api = wandb.Api()

# %%
# team, project, run_id = "tu18537", "pymxs", "8m6csih8"
# run = api.run(f"{team}/{project}/{run_id}")

# run.display(height=1080)  # you may need to zoom out to see the whole window!
# Out:
# /home/tu18537/miniconda3/envs/thesis_plotting/lib/python3.10/site-packages/IPython/core/display.py:431: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src='https://wandb.ai/tu18537/pymxs/runs/8m6csih8?jupyter=true' style='border:none;width:100%;height:1080px;'></iframe>
# True

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
runs = api.runs("tu18537/pymxs")

# example run to see config etc

history = []

run = api.run("tu18537/pymxs/8m6csih8")
hist = run.history(keys=['rollout/ep_rew_mean'])

print(run.history(keys=['rollout/ep_rew_mean']))


df = pd.DataFrame(hist)
df_sort = df.sort_values('_step')

df_sort.plot.line(x='_step', y = 'rollout/ep_rew_mean')

# vars(run)
# run.hostname

# for run in runs:
#     print(run.config["
# Out:
#      _step  rollout/ep_rew_mean
# 0    50297          3596.276367
# 1    59696          8158.760742
# 2     5534          2965.487061
# 3    65838          8839.141602
# 4    63335          7660.947266
# ..     ...                  ...
# 495  15527          2936.105225
# 496  43758          3148.239014
# 497  70206          7674.429688
# 498  49052          3625.041016
# 499   2508          2932.831299
#
# [500 rows x 2 columns]
# <Axes: xlabel='_step'>

# %%
#filter using mongodb lang

# runs = api.runs("tu18537/pymxs", {"state": "finished"})
runs = api.runs("tu18537/pymxs")
len(runs)
# Out:
# 2188
